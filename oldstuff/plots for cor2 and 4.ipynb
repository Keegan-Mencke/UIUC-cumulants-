# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cor2 = pd.read_csv('2nd corrilationv2_1.csv', usecols = [1])
cor2.to_numpy().flatten()
cor4 = pd.read_csv('4th corrilationv2_1.csv', usecols = [1])
cor4.to_numpy().flatten() 
def v2_cor2(cor_2): #equation 11 and 13
    #cor_2 should be your cumulant_moment array from above, array of cumulant order 2 for every event
    return np.sqrt(np.mean(cor_2))

def v2_cor4(cor_2, cor_4): #equation 12 and 14 
    #cor_2 should be your cumulant_moment array from above, array of cumulant order 2 for every event
    #cor_4 should be your cumulant_moment array from above, array of cumulant order 4 for every event
    return ((np.mean(cor_4)-2*(np.mean(cor_2))**2))**(1/4)  #equation says this should be negative sign inside the 1/4 root, but idkk
print(v2_cor2(cor2))
print(v2_cor4(cor2, cor4))
# Out:
# 0.09328071031456699
# 0.11235818345361341

# %%
plt.figure(0)
plt.hist(cor2, bins = 100)
plt.figure(1 )
plt.hist(cor4, bins = 100)
# Out:
# (array([2.00000e+00, 7.00000e+00, 7.00000e+00, 6.00000e+00, 9.00000e+00,
#         7.00000e+00, 1.70000e+01, 1.60000e+01, 1.10000e+01, 1.70000e+01,
#         2.10000e+01, 2.00000e+01, 1.80000e+01, 2.30000e+01, 2.40000e+01,
#         2.30000e+01, 2.20000e+01, 2.50000e+01, 2.50000e+01, 2.00000e+01,
#         3.80000e+01, 3.00000e+01, 3.20000e+01, 3.60000e+01, 3.70000e+01,
#         3.90000e+01, 4.60000e+01, 5.20000e+01, 5.60000e+01, 6.60000e+01,
#         7.20000e+01, 7.60000e+01, 9.00000e+01, 1.01000e+02, 1.09000e+02,
#         1.35000e+02, 1.56000e+02, 1.63000e+02, 2.07000e+02, 1.88000e+02,
#         2.66000e+02, 2.77000e+02, 3.25000e+02, 4.75000e+02, 6.01000e+02,
#         7.81000e+02, 1.17100e+03, 2.01700e+03, 4.41300e+03, 3.90660e+04,
#         3.35089e+05, 4.71700e+03, 2.15800e+03, 1.34700e+03, 8.98000e+02,
#         6.42000e+02, 5.05000e+02, 3.98000e+02, 3.70000e+02, 3.29000e+02,
#         2.55000e+02, 1.46000e+02, 1.08000e+02, 1.25000e+02, 1.16000e+02,
#         1.21000e+02, 8.50000e+01, 8.20000e+01, 8.60000e+01, 5.90000e+01,
#         6.40000e+01, 6.10000e+01, 5.60000e+01, 3.00000e+01, 5.60000e+01,
#         5.50000e+01, 4.90000e+01, 4.20000e+01, 4.50000e+01, 4.40000e+01,
#         4.10000e+01, 3.50000e+01, 3.60000e+01, 3.70000e+01, 2.40000e+01,
#         2.30000e+01, 2.60000e+01, 2.20000e+01, 2.70000e+01, 1.60000e+01,
#         2.60000e+01, 1.30000e+01, 1.50000e+01, 1.70000e+01, 1.50000e+01,
#         1.30000e+01, 1.20000e+01, 1.30000e+01, 5.00000e+00, 5.00000e+00]),
#  array([-9.93041981e-01, -9.73196452e-01, -9.53350923e-01, -9.33505393e-01,
#         -9.13659864e-01, -8.93814335e-01, -8.73968806e-01, -8.54123277e-01,
#         -8.34277747e-01, -8.14432218e-01, -7.94586689e-01, -7.74741160e-01,
#         -7.54895631e-01, -7.35050101e-01, -7.15204572e-01, -6.95359043e-01,
#         -6.75513514e-01, -6.55667984e-01, -6.35822455e-01, -6.15976926e-01,
#         -5.96131397e-01, -5.76285868e-01, -5.56440338e-01, -5.36594809e-01,
#         -5.16749280e-01, -4.96903751e-01, -4.77058221e-01, -4.57212692e-01,
#         -4.37367163e-01, -4.17521634e-01, -3.97676105e-01, -3.77830575e-01,
#         -3.57985046e-01, -3.38139517e-01, -3.18293988e-01, -2.98448459e-01,
#         -2.78602929e-01, -2.58757400e-01, -2.38911871e-01, -2.19066342e-01,
#         -1.99220812e-01, -1.79375283e-01, -1.59529754e-01, -1.39684225e-01,
#         -1.19838696e-01, -9.99931664e-02, -8.01476372e-02, -6.03021080e-02,
#         -4.04565788e-02, -2.06110496e-02, -7.65520345e-04,  1.90800089e-02,
#          3.89255381e-02,  5.87710673e-02,  7.86165965e-02,  9.84621257e-02,
#          1.18307655e-01,  1.38153184e-01,  1.57998713e-01,  1.77844243e-01,
#          1.97689772e-01,  2.17535301e-01,  2.37380830e-01,  2.57226359e-01,
#          2.77071889e-01,  2.96917418e-01,  3.16762947e-01,  3.36608476e-01,
#          3.56454006e-01,  3.76299535e-01,  3.96145064e-01,  4.15990593e-01,
#          4.35836122e-01,  4.55681652e-01,  4.75527181e-01,  4.95372710e-01,
#          5.15218239e-01,  5.35063768e-01,  5.54909298e-01,  5.74754827e-01,
#          5.94600356e-01,  6.14445885e-01,  6.34291415e-01,  6.54136944e-01,
#          6.73982473e-01,  6.93828002e-01,  7.13673531e-01,  7.33519061e-01,
#          7.53364590e-01,  7.73210119e-01,  7.93055648e-01,  8.12901177e-01,
#          8.32746707e-01,  8.52592236e-01,  8.72437765e-01,  8.92283294e-01,
#          9.12128824e-01,  9.31974353e-01,  9.51819882e-01,  9.71665411e-01,
#          9.91510940e-01]),
#  <BarContainer object of 100 artists>)

# %%
def v2_cor2(cor_2): #equation 11 and 13
    #cor_2 should be your cumulant_moment array from above, array of cumulant order 2 for every event
    return np.sqrt(np.mean(cor_2))

def v2_cor4(cor_2, cor_4): #equation 12 and 14 
    #cor_2 should be your cumulant_moment array from above, array of cumulant order 2 for every event
    #cor_4 should be your cumulant_moment array from above, array of cumulant order 4 for every event
    return (-1*(np.mean(cos_4)-2*(np.mean(cor_2))**2))**(1/4)
